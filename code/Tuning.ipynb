# %% [markdown]
# Imports

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from skimage.morphology import skeletonize
from sklearn.neighbors import KNeighborsClassifier
import os
from sklearn import svm, metrics
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from __future__ import division
from scipy.signal import convolve2d
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, StratifiedKFold,train_test_split, cross_val_score
from statistics import mean, stdev
tuning = False

# %% [markdown]
# Functions

# %%
def standardize_train(X):
    mu = np.mean(X,axis=0)
    sigma = np.std(X,axis=0)
    normalized_X = (X-mu)/sigma
    
    return normalized_X, mu, sigma

def standardize_test(X,mu,sigma):
    normalized_X = (X-mu)/sigma
    return normalized_X

# %%
## Reference: https://stackoverflow.com/questions/23548863/converting-a-specific-matlab-script-to-python/23575137
#Perform local Phase Quantization
def lpq(img, winSize = 3, freqestim = 1, mode = 'nh'):
    
    rho = 0.90
    STFTalpha = 1/winSize    # alpha in STFT approaches (for Gaussian derivative alpha=1)
    sigmaS = (winSize-1)/4   # Sigma for STFT Gaussian window (applied if freqestim==2)
    sigmaA = 8/(winSize-1)   # Sigma for Gaussian derivative quadrature filters (applied if freqestim==3)

    convmode = 'valid'   # Compute descriptor responses only on part that have full neigborhood. Use 'same' if all pixels are included (extrapolates np.image with zeros).

    img = np.float64(img)                # Convert np.image to double
    r = (winSize-1)/2                    # Get radius from window size
    x = np.arange(-r, r+1)[np.newaxis]   # Form spatial coordinates in window

    if freqestim == 1:  #  STFT uniform window
        # Basic STFT filters
        w0 = np.ones_like(x)
        w1 = np.exp(-2*np.pi*x*STFTalpha*1j)
        w2 = np.conj(w1)

    ## Run filters to compute the frequency response in the four points. Store np.real and np.imaginary parts separately
    # Run first filter
    filterResp1 = convolve2d(convolve2d(img,w0.T,convmode),w1,convmode)
    filterResp2 = convolve2d(convolve2d(img,w1.T,convmode),w0,convmode)
    filterResp3 = convolve2d(convolve2d(img,w1.T,convmode),w1,convmode)
    filterResp4 = convolve2d(convolve2d(img,w1.T,convmode),w2,convmode)

    # Initilize frequency domain matrix for four frequency coordinates (np.real and np.imaginary parts for each frequency).
    freqResp = np.dstack([filterResp1.real, filterResp1.imag,
                         filterResp2.real, filterResp2.imag,
                         filterResp3.real, filterResp3.imag,
                         filterResp4.real, filterResp4.imag])

    ## Perform quantization and compute LPQ codewords
    inds = np.arange(freqResp.shape[2])[np.newaxis,np.newaxis,:]
    LPQdesc = ((freqResp>0)*(2**inds)).sum(2)

    ## Switch format to uint8 if LPQ code np.image is required as output
    if mode =='im':
        LPQdesc = np.uint8(LPQdesc)

    ## Histogram if needed
    if mode == 'nh' or mode == 'h':
        LPQdesc = np.histogram(LPQdesc.flatten(),range(256))[0]

    ## Normalize histogram if needed
    if mode == 'nh':
        LPQdesc = LPQdesc/LPQdesc.sum()

    #print(LPQdesc)
    return LPQdesc

# %% [markdown]
# ## Preprocessing

# %%
# 1. Perform Preprocessing
def preprocessing(image):
    ret2,th2 = cv2.threshold(image, 0, 1, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    result = np.array(th2, dtype = 'float')
    return result

# %% [markdown]
# ## Feature Extraction

# %%
# 2. Feature Extraction using Local Phase Quantization
def extractFeatures(image):
    return lpq(image, winSize = 5, mode ='nh')

# %% [markdown]
# ## Classification

# %%
data = []
data_labels = []
# Read font names from file
fontFile = open("names.txt",'r')
fonts = np.loadtxt(fontFile, dtype='str')
for font in fonts:
    fontDir, fontName = font.split("___")
    print(fontDir, fontName)
    for file in os.listdir(fontDir):
        image = cv2.imread(fontDir+"/"+file,0)
        image_processed = preprocessing(image)
        data.append(image_processed)
        data_labels.append(fontName)

# Convert data to numpy array
data = np.asarray(data, dtype=np.ndarray)
data_labels = np.asarray(data_labels)
# Out:
# 1 diwani
# 2 naskh
# 3 parsi
# 4 rekaa
# 5 thuluth
# 6 maghribi
# 7 kufi
# 8 mohakek
# 9 Squar-kufic

# %%
N = data.shape[0]
trainFeatures = np.zeros((N, 255))

for i in range(trainFeatures.shape[0]):
    trainFeatures[i] = extractFeatures(data[i])

standardized_train, mu, sigma = standardize_train(trainFeatures)
standardized_test = standardize_test(trainFeatures,mu,sigma)
y_train = data_labels

# %% [markdown]
# ## Hyper-parameter Tuning

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
C_values = [2**(-5),2**(-3),2**(-1),2**1,2**3,2**5,2**7,2**9,2**10,2**11]
gamma_values = [2**(-15), 2**(-13), 2**(-11), 2**(-9), 2**(-7), 2**(-5), 2**(-3), 2**(-1), 2**(1),2**(3)]
kernels = ['rbf', 'poly', 'sigmoid']
maximum_acc = float('-inf')
maximum = []
stdv = 0
best_C = None
best_gamma = None
best_kernel = None
if tuning:
  for C_test in C_values:
    for gamma_test in gamma_values:
      for kernel_test in kernels:
        clf_accu_stratified = []
        clf_svm = svm.SVC(C=C_test, gamma=gamma_test, kernel=kernel_test)
        for train_index, test_index in skf.split(trainFeatures,y_train):
          x_train_fold, x_test_fold = standardized_train[train_index], standardized_test[test_index]
          y_train_fold, y_test_fold = y_train[train_index], y_train[test_index]
          clf_svm.fit(x_train_fold, y_train_fold)
          clf_accu_stratified.append(clf_svm.score(x_test_fold, y_test_fold))
        acc = mean(clf_accu_stratified)*100
        print('\nOverall Accuracy:', acc, '%')
        print('\nStandard Deviation is:', stdev(clf_accu_stratified))
        if acc >= maximum_acc:
          maximum_acc = acc
          best_C = C_test
          best_gamma = gamma_test
          best_kernel = kernel_test
          maximum.append((acc, best_C, best_gamma, best_kernel))
          stdv = stdev(clf_accu_stratified)
# Out:
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 40.474777448071215 %
#
# Standard Deviation is: 0.01320391422034836
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 41.66172106824926 %
#
# Standard Deviation is: 0.017754629438162136
#
# Overall Accuracy: 17.804154302670625 %
#
# Standard Deviation is: 0.05013870993684214
#
# Overall Accuracy: 38.21958456973294 %
#
# Standard Deviation is: 0.011757633683180396
#
# Overall Accuracy: 67.83382789317508 %
#
# Standard Deviation is: 0.011415658196837587
#
# Overall Accuracy: 25.341246290801188 %
#
# Standard Deviation is: 0.04656957827324465
#
# Overall Accuracy: 57.32937685459941 %
#
# Standard Deviation is: 0.014747505803904026
#
# Overall Accuracy: 85.4005934718101 %
#
# Standard Deviation is: 0.020169312128150062
#
# Overall Accuracy: 52.70029673590505 %
#
# Standard Deviation is: 0.013369590891476334
#
# Overall Accuracy: 73.53115727002968 %
#
# Standard Deviation is: 0.02503860309760118
#
# Overall Accuracy: 53.64985163204747 %
#
# Standard Deviation is: 0.03050756833821929
#
# Overall Accuracy: 98.33827893175075 %
#
# Standard Deviation is: 0.008287382815293174
#
# Overall Accuracy: 43.32344213649852 %
#
# Standard Deviation is: 0.01584136239173785
#
# Overall Accuracy: 14.896142433234422 %
#
# Standard Deviation is: 0.010149929600289063
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 28.01186943620178 %
#
# Standard Deviation is: 0.01385473890792729
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 27.062314540059347 %
#
# Standard Deviation is: 0.01333662021023397
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 27.121661721068246 %
#
# Standard Deviation is: 0.015785680805068716
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 27.062314540059347 %
#
# Standard Deviation is: 0.015475851407009257
#
# Overall Accuracy: 38.39762611275964 %
#
# Standard Deviation is: 0.012866162248474073
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 40.53412462908012 %
#
# Standard Deviation is: 0.013533239467052087
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 37.388724035608305 %
#
# Standard Deviation is: 0.014384806698564779
#
# Overall Accuracy: 70.38575667655786 %
#
# Standard Deviation is: 0.01382292545857818
#
# Overall Accuracy: 17.744807121661722 %
#
# Standard Deviation is: 0.043983028267919264
#
# Overall Accuracy: 57.2106824925816 %
#
# Standard Deviation is: 0.011943389790800068
#
# Overall Accuracy: 91.4540059347181 %
#
# Standard Deviation is: 0.014597476410977861
#
# Overall Accuracy: 34.83679525222552 %
#
# Standard Deviation is: 0.0171234872952564
#
# Overall Accuracy: 84.33234421364986 %
#
# Standard Deviation is: 0.008752451752968892
#
# Overall Accuracy: 92.34421364985162 %
#
# Standard Deviation is: 0.017353343047137603
#
# Overall Accuracy: 88.96142433234422 %
#
# Standard Deviation is: 0.016306981203601273
#
# Overall Accuracy: 82.6112759643917 %
#
# Standard Deviation is: 0.018953969641152892
#
# Overall Accuracy: 79.34718100890208 %
#
# Standard Deviation is: 0.024612986769528424
#
# Overall Accuracy: 98.33827893175075 %
#
# Standard Deviation is: 0.00854887851091275
#
# Overall Accuracy: 49.02077151335312 %
#
# Standard Deviation is: 0.007962259860533382
#
# Overall Accuracy: 28.6053412462908 %
#
# Standard Deviation is: 0.022946723951550407
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 30.56379821958457 %
#
# Standard Deviation is: 0.012763093868015784
#
# Overall Accuracy: 14.3026706231454 %
#
# Standard Deviation is: 0.009000445630921717
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 29.673590504451035 %
#
# Standard Deviation is: 0.014836795252225537
#
# Overall Accuracy: 11.632047477744807 %
#
# Standard Deviation is: 0.0013270433100888983
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 28.90207715133531 %
#
# Standard Deviation is: 0.009751736928875356
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 28.6053412462908 %
#
# Standard Deviation is: 0.017878184369604828
#
# Overall Accuracy: 40.296735905044514 %
#
# Standard Deviation is: 0.011757633683180375
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 37.1513353115727 %
#
# Standard Deviation is: 0.014137838871895077
#
# Overall Accuracy: 72.28486646884274 %
#
# Standard Deviation is: 0.013533239467052083
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 57.1513353115727 %
#
# Standard Deviation is: 0.0114156581968376
#
# Overall Accuracy: 92.81899109792285 %
#
# Standard Deviation is: 0.01644141860794666
#
# Overall Accuracy: 21.72106824925816 %
#
# Standard Deviation is: 0.04286781261669112
#
# Overall Accuracy: 84.74777448071217 %
#
# Standard Deviation is: 0.008287382815293117
#
# Overall Accuracy: 97.1513353115727 %
#
# Standard Deviation is: 0.009289303170622286
#
# Overall Accuracy: 39.287833827893174 %
#
# Standard Deviation is: 0.011980195393582397
#
# Overall Accuracy: 94.59940652818992 %
#
# Standard Deviation is: 0.011377026417021275
#
# Overall Accuracy: 96.37982195845697 %
#
# Standard Deviation is: 0.016441418607946654
#
# Overall Accuracy: 95.90504451038576 %
#
# Standard Deviation is: 0.010574795063029916
#
# Overall Accuracy: 82.90801186943621 %
#
# Standard Deviation is: 0.012693916698045976
#
# Overall Accuracy: 87.77448071216617 %
#
# Standard Deviation is: 0.02747011705883232
#
# Overall Accuracy: 98.51632047477746 %
#
# Standard Deviation is: 0.008126447440729495
#
# Overall Accuracy: 49.79228486646884 %
#
# Standard Deviation is: 0.020707829462751206
#
# Overall Accuracy: 57.80415430267062 %
#
# Standard Deviation is: 0.026324338416874645
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 31.454005934718097 %
#
# Standard Deviation is: 0.006635216550444485
#
# Overall Accuracy: 21.18694362017804 %
#
# Standard Deviation is: 0.013369590891476322
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 29.080118694362017 %
#
# Standard Deviation is: 0.011102840910308437
#
# Overall Accuracy: 14.362017804154304 %
#
# Standard Deviation is: 0.0053904754078887025
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 27.359050445103854 %
#
# Standard Deviation is: 0.024052087987132872
#
# Overall Accuracy: 11.98813056379822 %
#
# Standard Deviation is: 0.00338330986676302
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 28.902077151335316 %
#
# Standard Deviation is: 0.041149043183261305
#
# Overall Accuracy: 72.58160237388725 %
#
# Standard Deviation is: 0.014627605393313037
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 57.1513353115727 %
#
# Standard Deviation is: 0.0114156581968376
#
# Overall Accuracy: 92.99703264094956 %
#
# Standard Deviation is: 0.01673337944198419
#
# Overall Accuracy: 17.804154302670625 %
#
# Standard Deviation is: 0.05013870993684214
#
# Overall Accuracy: 84.86646884272997 %
#
# Standard Deviation is: 0.00865126393893959
#
# Overall Accuracy: 97.3293768545994 %
#
# Standard Deviation is: 0.011492532184591758
#
# Overall Accuracy: 25.341246290801188 %
#
# Standard Deviation is: 0.04656957827324465
#
# Overall Accuracy: 95.66765578635015 %
#
# Standard Deviation is: 0.010616346480711136
#
# Overall Accuracy: 98.33827893175075 %
#
# Standard Deviation is: 0.010616346480711192
#
# Overall Accuracy: 52.70029673590505 %
#
# Standard Deviation is: 0.013369590891476334
#
# Overall Accuracy: 93.76854599406528 %
#
# Standard Deviation is: 0.016785917654280055
#
# Overall Accuracy: 98.04154302670624 %
#
# Standard Deviation is: 0.012866162248474085
#
# Overall Accuracy: 98.33827893175075 %
#
# Standard Deviation is: 0.008287382815293174
#
# Overall Accuracy: 80.23738872403561 %
#
# Standard Deviation is: 0.01872024960900596
#
# Overall Accuracy: 92.34421364985164 %
#
# Standard Deviation is: 0.01098323769930071
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 44.45103857566765 %
#
# Standard Deviation is: 0.0153329503652983
#
# Overall Accuracy: 74.1839762611276 %
#
# Standard Deviation is: 0.02914967760295031
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 34.362017804154306 %
#
# Standard Deviation is: 0.04707731733130996
#
# Overall Accuracy: 37.032640949554896 %
#
# Standard Deviation is: 0.02049412065261959
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 30.50445103857567 %
#
# Standard Deviation is: 0.03955613159521201
#
# Overall Accuracy: 20.712166172106823 %
#
# Standard Deviation is: 0.011757633683180392
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 32.759643916913944 %
#
# Standard Deviation is: 0.022165993349534837
#
# Overall Accuracy: 16.795252225519288 %
#
# Standard Deviation is: 0.008802609480232247
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 33.88724035608309 %
#
# Standard Deviation is: 0.020813861028783614
#
# Overall Accuracy: 92.99703264094956 %
#
# Standard Deviation is: 0.01673337944198419
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 84.86646884272997 %
#
# Standard Deviation is: 0.00865126393893959
#
# Overall Accuracy: 97.3293768545994 %
#
# Standard Deviation is: 0.011492532184591758
#
# Overall Accuracy: 17.744807121661722 %
#
# Standard Deviation is: 0.043983028267919264
#
# Overall Accuracy: 95.72700296735906 %
#
# Standard Deviation is: 0.011795018940268092
#
# Overall Accuracy: 98.39762611275964 %
#
# Standard Deviation is: 0.010616346480711194
#
# Overall Accuracy: 34.83679525222552 %
#
# Standard Deviation is: 0.0171234872952564
#
# Overall Accuracy: 97.80415430267063 %
#
# Standard Deviation is: 0.010821710699590804
#
# Overall Accuracy: 99.28783382789318 %
#
# Standard Deviation is: 0.005390475407888694
#
# Overall Accuracy: 88.96142433234422 %
#
# Standard Deviation is: 0.016306981203601273
#
# Overall Accuracy: 93.70919881305639 %
#
# Standard Deviation is: 0.009930682807526143
#
# Overall Accuracy: 98.45697329376854 %
#
# Standard Deviation is: 0.008497223182953356
#
# Overall Accuracy: 98.33827893175075 %
#
# Standard Deviation is: 0.00854887851091275
#
# Overall Accuracy: 77.0326409495549 %
#
# Standard Deviation is: 0.02835342239902967
#
# Overall Accuracy: 92.52225519287833 %
#
# Standard Deviation is: 0.010364539582535864
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 41.12759643916914 %
#
# Standard Deviation is: 0.023515267366360764
#
# Overall Accuracy: 74.1839762611276 %
#
# Standard Deviation is: 0.02914967760295031
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 33.175074183976264 %
#
# Standard Deviation is: 0.052472775902391744
#
# Overall Accuracy: 37.032640949554896 %
#
# Standard Deviation is: 0.02049412065261959
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 29.73293768545994 %
#
# Standard Deviation is: 0.0365479388432099
#
# Overall Accuracy: 20.712166172106823 %
#
# Standard Deviation is: 0.011757633683180392
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 33.11572700296736 %
#
# Standard Deviation is: 0.03158530347949002
#
# Overall Accuracy: 16.795252225519288 %
#
# Standard Deviation is: 0.008802609480232247
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 34.302670623145396 %
#
# Standard Deviation is: 0.018837472104574343
#
# Overall Accuracy: 97.3293768545994 %
#
# Standard Deviation is: 0.011492532184591758
#
# Overall Accuracy: 11.572700296735905 %
#
# Standard Deviation is: 0.0
#
# Overall Accuracy: 95.72700296735906 %
#
# Standard Deviation is: 0.011795018940268092
#
# Overall Accuracy: 98.39762611275964 %
#
# Standard Deviation is: 0.011415658196837613
#
# Overall Accuracy: 21.72106824925816 %
#
# Standard Deviation is: 0.04286781261669112
#
# Overall Accuracy: 97.74480712166172 %
#
# Standard Deviation is: 0.01179501894026814
#
# Overall Accuracy: 99.22848664688428 %
#
# Standard Deviation is: 0.004500222815460848
#
# Overall Accuracy: 39.287833827893174 %
#
# Standard Deviation is: 0.011980195393582397
#
# Overall Accuracy: 98.27893175074183 %
#
# Standard Deviation is: 0.010983237699300765
#
# Overall Accuracy: 99.46587537091989 %
#
# Standard Deviation is: 0.004401304740116107
#
# Overall Accuracy: 95.90504451038576 %
#
# Standard Deviation is: 0.010574795063029916
#
# Overall Accuracy: 91.513353115727 %
#
# Standard Deviation is: 0.01646817439229864
#
# Overall Accuracy: 98.51632047477746 %
#
# Standard Deviation is: 0.009383613234921033
#
# Overall Accuracy: 98.51632047477746 %
#
# Standard Deviation is: 0.008126447440729495
#
# Overall Accuracy: 74.5994065281899 %
#
# Standard Deviation is: 0.02304245538079188
#
# Overall Accuracy: 92.52225519287833 %
#
# Standard Deviation is: 0.010364539582535864
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 41.18694362017804 %
#
# Standard Deviation is: 0.02005987392422025
#
# Overall Accuracy: 74.1839762611276 %
#
# Standard Deviation is: 0.02914967760295031
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 31.869436201780417 %
#
# Standard Deviation is: 0.04887592570892466
#
# Overall Accuracy: 37.032640949554896 %
#
# Standard Deviation is: 0.02049412065261959
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 30.326409495548962 %
#
# Standard Deviation is: 0.044132919744992775
#
# Overall Accuracy: 20.712166172106823 %
#
# Standard Deviation is: 0.011757633683180392
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 32.997032640949556 %
#
# Standard Deviation is: 0.03594058618074721
#
# Overall Accuracy: 16.795252225519288 %
#
# Standard Deviation is: 0.008802609480232247
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 34.480712166172104 %
#
# Standard Deviation is: 0.017226024063738875
#
# Overall Accuracy: 98.45697329376854 %
#
# Standard Deviation is: 0.01265918635471903
#
# Overall Accuracy: 17.804154302670625 %
#
# Standard Deviation is: 0.05013870993684214
#
# Overall Accuracy: 97.74480712166172 %
#
# Standard Deviation is: 0.01179501894026814
#
# Overall Accuracy: 99.05044510385757 %
#
# Standard Deviation is: 0.006081276418967103
#
# Overall Accuracy: 25.341246290801188 %
#
# Standard Deviation is: 0.04656957827324465
#
# Overall Accuracy: 98.63501483679525 %
#
# Standard Deviation is: 0.010193213078526824
#
# Overall Accuracy: 99.28783382789318 %
#
# Standard Deviation is: 0.005390475407888694
#
# Overall Accuracy: 52.70029673590505 %
#
# Standard Deviation is: 0.013369590891476334
#
# Overall Accuracy: 98.27893175074183 %
#
# Standard Deviation is: 0.009241787241778916
#
# Overall Accuracy: 99.34718100890207 %
#
# Standard Deviation is: 0.0048758684644376665
#
# Overall Accuracy: 98.33827893175075 %
#
# Standard Deviation is: 0.008287382815293174
#
# Overall Accuracy: 90.08902077151335 %
#
# Standard Deviation is: 0.014777328899689902
#
# Overall Accuracy: 98.51632047477746 %
#
# Standard Deviation is: 0.009383613234921033
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 73.53115727002968 %
#
# Standard Deviation is: 0.02340266368324075
#
# Overall Accuracy: 92.52225519287833 %
#
# Standard Deviation is: 0.010364539582535864
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 42.72997032640949 %
#
# Standard Deviation is: 0.02791526368282904
#
# Overall Accuracy: 74.1839762611276 %
#
# Standard Deviation is: 0.02914967760295031
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 32.87833827893175 %
#
# Standard Deviation is: 0.0483688627465281
#
# Overall Accuracy: 37.032640949554896 %
#
# Standard Deviation is: 0.02049412065261959
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 30.14836795252226 %
#
# Standard Deviation is: 0.038893916623883536
#
# Overall Accuracy: 20.712166172106823 %
#
# Standard Deviation is: 0.011757633683180392
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 33.88724035608309 %
#
# Standard Deviation is: 0.031008547127865004
#
# Overall Accuracy: 16.795252225519288 %
#
# Standard Deviation is: 0.008802609480232247
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 34.302670623145396 %
#
# Standard Deviation is: 0.017754629438162133
#
# Overall Accuracy: 98.99109792284867 %
#
# Standard Deviation is: 0.006501157952583555
#
# Overall Accuracy: 17.744807121661722 %
#
# Standard Deviation is: 0.043983028267919264
#
# Overall Accuracy: 98.63501483679525 %
#
# Standard Deviation is: 0.010193213078526824
#
# Overall Accuracy: 99.22848664688428 %
#
# Standard Deviation is: 0.005390475407888694
#
# Overall Accuracy: 34.83679525222552 %
#
# Standard Deviation is: 0.0171234872952564
#
# Overall Accuracy: 98.81305637982196 %
#
# Standard Deviation is: 0.00695907382763118
#
# Overall Accuracy: 99.16913946587538 %
#
# Standard Deviation is: 0.00570782909841878
#
# Overall Accuracy: 88.96142433234422 %
#
# Standard Deviation is: 0.016306981203601273
#
# Overall Accuracy: 98.33827893175075 %
#
# Standard Deviation is: 0.0092893031706223
#
# Overall Accuracy: 99.28783382789318 %
#
# Standard Deviation is: 0.003981129930266676
#
# Overall Accuracy: 98.33827893175075 %
#
# Standard Deviation is: 0.00854887851091275
#
# Overall Accuracy: 89.79228486646885 %
#
# Standard Deviation is: 0.016733379441984206
#
# Overall Accuracy: 98.51632047477746 %
#
# Standard Deviation is: 0.009383613234921033
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 73.59050445103857 %
#
# Standard Deviation is: 0.02473788130642888
#
# Overall Accuracy: 92.52225519287833 %
#
# Standard Deviation is: 0.010364539582535864
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 43.08605341246291 %
#
# Standard Deviation is: 0.03136148982935394
#
# Overall Accuracy: 74.1839762611276 %
#
# Standard Deviation is: 0.02914967760295031
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 32.87833827893175 %
#
# Standard Deviation is: 0.04656012348109093
#
# Overall Accuracy: 37.032640949554896 %
#
# Standard Deviation is: 0.02049412065261959
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 31.15727002967359 %
#
# Standard Deviation is: 0.03986655442891515
#
# Overall Accuracy: 20.712166172106823 %
#
# Standard Deviation is: 0.011757633683180392
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 32.047477744807125 %
#
# Standard Deviation is: 0.018292029682400516
#
# Overall Accuracy: 16.795252225519288 %
#
# Standard Deviation is: 0.008802609480232247
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 34.124629080118694 %
#
# Standard Deviation is: 0.02129480726173193
#
# Overall Accuracy: 98.87240356083086 %
#
# Standard Deviation is: 0.007084472632826877
#
# Overall Accuracy: 19.703264094955493 %
#
# Standard Deviation is: 0.046189877046933434
#
# Overall Accuracy: 98.87240356083086 %
#
# Standard Deviation is: 0.006433081124237014
#
# Overall Accuracy: 99.16913946587538 %
#
# Standard Deviation is: 0.006433081124237014
#
# Overall Accuracy: 36.439169139465875 %
#
# Standard Deviation is: 0.014747505803904064
#
# Overall Accuracy: 99.05044510385757 %
#
# Standard Deviation is: 0.0038689628517523025
#
# Overall Accuracy: 99.10979228486647 %
#
# Standard Deviation is: 0.00469180661746049
#
# Overall Accuracy: 93.35311572700297 %
#
# Standard Deviation is: 0.01179501894026813
#
# Overall Accuracy: 98.45697329376854 %
#
# Standard Deviation is: 0.008752451752968928
#
# Overall Accuracy: 99.28783382789318 %
#
# Standard Deviation is: 0.003981129930266676
#
# Overall Accuracy: 98.33827893175075 %
#
# Standard Deviation is: 0.009289303170622296
#
# Overall Accuracy: 89.61424332344214 %
#
# Standard Deviation is: 0.016654261365462657
#
# Overall Accuracy: 98.51632047477746 %
#
# Standard Deviation is: 0.009383613234921033
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 73.47181008902078 %
#
# Standard Deviation is: 0.02496817088185475
#
# Overall Accuracy: 92.52225519287833 %
#
# Standard Deviation is: 0.010364539582535864
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 43.20474777448071 %
#
# Standard Deviation is: 0.027883703171118122
#
# Overall Accuracy: 74.1839762611276 %
#
# Standard Deviation is: 0.02914967760295031
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 33.590504451038576 %
#
# Standard Deviation is: 0.03796596463278803
#
# Overall Accuracy: 37.032640949554896 %
#
# Standard Deviation is: 0.02049412065261959
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 31.3353115727003 %
#
# Standard Deviation is: 0.03826627812849302
#
# Overall Accuracy: 20.712166172106823 %
#
# Standard Deviation is: 0.011757633683180392
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 33.05637982195846 %
#
# Standard Deviation is: 0.013369590891476322
#
# Overall Accuracy: 16.795252225519288 %
#
# Standard Deviation is: 0.008802609480232247
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 34.124629080118694 %
#
# Standard Deviation is: 0.022598733251821677
#
# Overall Accuracy: 99.10979228486647 %
#
# Standard Deviation is: 0.005934718100890191
#
# Overall Accuracy: 21.72106824925816 %
#
# Standard Deviation is: 0.04286781261669112
#
# Overall Accuracy: 98.81305637982196 %
#
# Standard Deviation is: 0.00695907382763118
#
# Overall Accuracy: 99.16913946587538 %
#
# Standard Deviation is: 0.006433081124237014
#
# Overall Accuracy: 39.287833827893174 %
#
# Standard Deviation is: 0.011980195393582397
#
# Overall Accuracy: 98.87240356083086 %
#
# Standard Deviation is: 0.004401304740116107
#
# Overall Accuracy: 99.10979228486647 %
#
# Standard Deviation is: 0.00469180661746049
#
# Overall Accuracy: 95.90504451038576 %
#
# Standard Deviation is: 0.010574795063029916
#
# Overall Accuracy: 98.45697329376854 %
#
# Standard Deviation is: 0.006766619733526056
#
# Overall Accuracy: 99.28783382789318 %
#
# Standard Deviation is: 0.003981129930266676
#
# Overall Accuracy: 98.51632047477746 %
#
# Standard Deviation is: 0.008126447440729495
#
# Overall Accuracy: 89.61424332344214 %
#
# Standard Deviation is: 0.016654261365462657
#
# Overall Accuracy: 98.51632047477746 %
#
# Standard Deviation is: 0.009383613234921033
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 73.53115727002967 %
#
# Standard Deviation is: 0.02530097774159312
#
# Overall Accuracy: 92.52225519287833 %
#
# Standard Deviation is: 0.010364539582535864
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 43.20474777448071 %
#
# Standard Deviation is: 0.02827567774379014
#
# Overall Accuracy: 74.1839762611276 %
#
# Standard Deviation is: 0.02914967760295031
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 33.175074183976264 %
#
# Standard Deviation is: 0.04113834261275577
#
# Overall Accuracy: 37.032640949554896 %
#
# Standard Deviation is: 0.02049412065261959
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 31.03857566765579 %
#
# Standard Deviation is: 0.044490598964964545
#
# Overall Accuracy: 20.712166172106823 %
#
# Standard Deviation is: 0.011757633683180392
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 33.175074183976264 %
#
# Standard Deviation is: 0.012306493384764219
#
# Overall Accuracy: 16.795252225519288 %
#
# Standard Deviation is: 0.008802609480232247
#
# Overall Accuracy: 98.57566765578635 %
#
# Standard Deviation is: 0.008497223182953352
#
# Overall Accuracy: 34.2433234421365 %
#
# Standard Deviation is: 0.02125341789848069

# %%
if tuning:
  maximum.sort(reverse=True)
  print(maximum[0])
  print(maximum[1])
  print(maximum[2])
  print(maximum[3])
  print(maximum[4])
# Out:
# (99.46587537091989, 32, 0.001953125, 'rbf')
# (99.28783382789318, 8, 0.001953125, 'rbf')
# (98.57566765578635, 2, 8, 'poly')
# (98.57566765578635, 2, 2, 'poly')
# (98.57566765578635, 2, 0.5, 'poly')

# %% [markdown]
# ## Combining Classifiers

# %%
clf_knn = KNeighborsClassifier(n_neighbors=5)
clf_svm1 = svm.SVC(C=32, gamma=0.001953125, kernel='rbf')
clf_svm2 = svm.SVC(C=8, gamma=0.001953125, kernel='rbf')
clf_svm3 = svm.SVC(C=2, gamma=8, kernel='poly')
clf_svm4 = svm.SVC(C=2, gamma=2, kernel='poly')

# %% [markdown]
# Majority vote using stratified cross validation k = 10

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
for train_index, test_index in skf.split(trainFeatures,y_train):
        x_train_fold, x_test_fold = standardized_train[train_index], standardized_test[test_index]
        y_train_fold, y_test_fold = y_train[train_index], y_train[test_index]
        clf_max = VotingClassifier(estimators=[('knn', clf_knn),('svm1', clf_svm1),('svm2', clf_svm2),('svm3', clf_svm3),('svm4', clf_svm4)], voting='hard')

        clf_max.fit(x_train_fold, y_train_fold)
        y_pred_max = clf_max.predict(x_test_fold)
        print("Accuracy-Majority Vote:",metrics.accuracy_score(y_test_fold, y_pred_max)*100)
        print("F1 Score Micro-Majority Vote:",metrics.f1_score(y_test_fold, y_pred_max, average='micro')*100)
        print('--------------------------------------------------')
# Out:
# Accuracy-Majority Vote: 100.0
# F1 Score Micro-Majority Vote: 100.0
# --------------------------------------------------
# Accuracy-Majority Vote: 99.40828402366864
# F1 Score Micro-Majority Vote: 99.40828402366864
# --------------------------------------------------
# Accuracy-Majority Vote: 100.0
# F1 Score Micro-Majority Vote: 100.0
# --------------------------------------------------
# Accuracy-Majority Vote: 99.40828402366864
# F1 Score Micro-Majority Vote: 99.40828402366864
# --------------------------------------------------
# Accuracy-Majority Vote: 100.0
# F1 Score Micro-Majority Vote: 100.0
# --------------------------------------------------
# Accuracy-Majority Vote: 98.21428571428571
# F1 Score Micro-Majority Vote: 98.21428571428571
# --------------------------------------------------
# Accuracy-Majority Vote: 98.80952380952381
# F1 Score Micro-Majority Vote: 98.80952380952381
# --------------------------------------------------
# Accuracy-Majority Vote: 100.0
# F1 Score Micro-Majority Vote: 100.0
# --------------------------------------------------
# Accuracy-Majority Vote: 99.40476190476191
# F1 Score Micro-Majority Vote: 99.40476190476191
# --------------------------------------------------
# Accuracy-Majority Vote: 98.80952380952381
# F1 Score Micro-Majority Vote: 98.80952380952381
# --------------------------------------------------

# %% [markdown]
# Majority Vote using stratified cross validation k = 5

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

for train_index, test_index in skf.split(trainFeatures,y_train):
        x_train_fold, x_test_fold = standardized_train[train_index], standardized_test[test_index]
        y_train_fold, y_test_fold = y_train[train_index], y_train[test_index]
        clf_max = VotingClassifier(estimators=[('knn', clf_knn),('svm1', clf_svm1),('svm2', clf_svm2),('svm3', clf_svm3),('svm4', clf_svm4)], voting='hard')

        clf_max.fit(x_train_fold, y_train_fold)
        y_pred_max = clf_max.predict(x_test_fold)
        print("Accuracy-Majority Vote:",metrics.accuracy_score(y_test_fold, y_pred_max)*100)
        print("F1 Score Micro-Majority Vote:",metrics.f1_score(y_test_fold, y_pred_max, average='micro')*100)
        print('--------------------------------------------------')
# Out:
# Accuracy-Majority Vote: 100.0
# F1 Score Micro-Majority Vote: 100.0
# --------------------------------------------------
# Accuracy-Majority Vote: 100.0
# F1 Score Micro-Majority Vote: 100.0
# --------------------------------------------------
# Accuracy-Majority Vote: 99.10979228486647
# F1 Score Micro-Majority Vote: 99.10979228486647
# --------------------------------------------------
# Accuracy-Majority Vote: 99.40652818991099
# F1 Score Micro-Majority Vote: 99.40652818991099
# --------------------------------------------------
# Accuracy-Majority Vote: 98.81305637982196
# F1 Score Micro-Majority Vote: 98.81305637982196
# --------------------------------------------------

# %% [markdown]
# Majority Vote using normal cross validation k = 10

# %%
clf_max = VotingClassifier(estimators=[('knn', clf_knn),('svm1', clf_svm1),('svm2', clf_svm2),('svm3', clf_svm3),('svm4', clf_svm4)], voting='hard')
scores = cross_val_score(clf_max, standardized_train, y_train, cv=10, scoring='f1_macro')
print(scores) 
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# [0.95279675 0.99399399 0.96261002 1.         1.         1.
#  1.         1.         0.9755913  0.92782858]
# 0.98 accuracy with a standard deviation of 0.02

# %% [markdown]
# Majority Vote using normal cross validation k = 5

# %%
clf_max = VotingClassifier(estimators=[('knn', clf_knn),('svm1', clf_svm1),('svm2', clf_svm2),('svm3', clf_svm3),('svm4', clf_svm4)], voting='hard')
scores = cross_val_score(clf_max, standardized_train, y_train, cv=5, scoring='f1_macro')
print(scores) 
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# [0.94824431 0.96991659 1.         0.99397639 0.93286553]
# 0.97 accuracy with a standard deviation of 0.03

# %% [markdown]
# ## Soft Majority Vote (Sum)

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
clf_svm1 = svm.SVC(C=32, gamma=0.001953125, kernel='rbf',probability=True)
clf_svm2 = svm.SVC(C=8, gamma=0.001953125, kernel='rbf',probability=True)
clf_svm3 = svm.SVC(C=2, gamma=8, kernel='poly',probability=True)
clf_svm4 = svm.SVC(C=2, gamma=2, kernel='poly',probability=True)
for train_index, test_index in skf.split(trainFeatures,y_train):
        x_train_fold, x_test_fold = standardized_train[train_index], standardized_test[test_index]
        y_train_fold, y_test_fold = y_train[train_index], y_train[test_index]
        clf_sum = VotingClassifier(estimators=[('knn', clf_knn),('svm1', clf_svm1),('svm2', clf_svm2),('svm3', clf_svm3),('svm4', clf_svm4)], voting='soft')
        clf_sum.fit(x_train_fold, y_train_fold)
        y_pred_max = clf_sum.predict(x_test_fold)
        print("Accuracy - Majority Vote:",metrics.accuracy_score(y_test_fold, y_pred_max)*100)
        print("F1 Score - Micro:",metrics.f1_score(y_test_fold, y_pred_max, average='micro')*100)
        print('_________________________________________')
# Out:
# Accuracy - Majority Vote: 100.0
# F1 Score - Micro: 100.0
# _________________________________________
# Accuracy - Majority Vote: 99.40828402366864
# F1 Score - Micro: 99.40828402366864
# _________________________________________
# Accuracy - Majority Vote: 100.0
# F1 Score - Micro: 100.0
# _________________________________________
# Accuracy - Majority Vote: 100.0
# F1 Score - Micro: 100.0
# _________________________________________
# Accuracy - Majority Vote: 100.0
# F1 Score - Micro: 100.0
# _________________________________________
# Accuracy - Majority Vote: 98.80952380952381
# F1 Score - Micro: 98.80952380952381
# _________________________________________
# Accuracy - Majority Vote: 98.80952380952381
# F1 Score - Micro: 98.80952380952381
# _________________________________________
# Accuracy - Majority Vote: 100.0
# F1 Score - Micro: 100.0
# _________________________________________
# Accuracy - Majority Vote: 99.40476190476191
# F1 Score - Micro: 99.40476190476191
# _________________________________________
# Accuracy - Majority Vote: 99.40476190476191
# F1 Score - Micro: 99.40476190476191
# _________________________________________
